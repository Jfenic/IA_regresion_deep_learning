# %% [markdown]
# # Ejercicios de Deep Learning: LSTM y CNN con Keras
#
# Plantilla para resolver los ejercicios de la asignatura. Completa cada sección con tu código y comentarios.

# %% [markdown]
# ## 1. Importar librerías necesarias
# Importa todas las librerías que utilizarás en ambos ejercicios.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, confusion_matrix, accuracy_score
from tensorflow import keras
from tensorflow.keras import layers

# %% [markdown]
# ---
# # Ejercicio 1: Red Neuronal LSTM para Series Temporales
#
# Completa cada celda siguiendo los pasos indicados en el enunciado.

# %% [markdown]
# ### 1.1 Cargar y preprocesar los datos de series temporales
# (Puedes generar datos sintéticos o cargar un dataset real)

# %%
# TODO: Generar o cargar datos de series temporales
# Normalizar y dividir en train/test
# Reestructurar al formato [muestras, pasos de tiempo, características]

# %% [markdown]
# ### 1.2 Definir y compilar el modelo LSTM
# (Utiliza keras.Sequential y capas LSTM)

# %%
# TODO: Definir el modelo LSTM
# Compilar el modelo con función de pérdida y optimizador adecuados

# %% [markdown]
# ### 1.3 Entrenar el modelo LSTM
# (Entrena el modelo y guarda el historial)

# %%
# TODO: Entrenar el modelo y guardar el historial

# %% [markdown]
# ### 1.4 Evaluar y visualizar resultados del modelo LSTM
# (Evalúa en test y grafica la pérdida y las predicciones)

# %%
# TODO: Evaluar el modelo, graficar la pérdida y comparar predicciones vs reales

# %% [markdown]
# ---
# # Ejercicio 2: Red Neuronal Convolucional (CNN) para CIFAR-10
#
# Completa cada celda siguiendo los pasos indicados en el enunciado.

# %% [markdown]
# ### 2.1 Cargar y preprocesar el dataset CIFAR-10
# (Normaliza imágenes y convierte etiquetas a categóricas)

# %%
# TODO: Cargar y preprocesar CIFAR-10

# %% [markdown]
# ### 2.2 Definir y compilar el modelo CNN
# (Utiliza capas Conv2D, MaxPooling, Dense y Softmax)

# %%
# TODO: Definir la arquitectura CNN y compilar el modelo

# %% [markdown]
# ### 2.3 Entrenar el modelo CNN
# (Entrena el modelo y valida con parte de los datos)

# %%
# TODO: Entrenar el modelo y guardar el historial

# %% [markdown]
# ### 2.4 Evaluar y visualizar resultados del modelo CNN
# (Evalúa en test, grafica pérdida, precisión y matriz de confusión)

# %%
# TODO: Evaluar el modelo, graficar resultados y mostrar matriz de confusión

# %% [markdown]
# ---
# # Conclusiones
# Redacta aquí un breve informe (1-2 párrafos) resumiendo el rendimiento de ambos modelos, la precisión obtenida y observaciones relevantes.
